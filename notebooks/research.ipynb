# %%
import logging
import os
from datetime import datetime



datetime.now()


f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
os.path.join(os.getcwd(),"logs")
from src.FlightFarePredictionS.logger import logging
logging.info("i've created log file and testing it")
import sys


class customexception(Exception):
    def __init__(self,error_message,error_details:sys):
        self.error_message = error_message
        _,_,exc_tb = error_details.exc_info()
        
        self.lineno=exc_tb.tb_lineno
        self.file_name=exc_tb.tb_frame.f_code.co_filename 
    
    def __str__(self):
        return "Error occured in python script name [{0}] line number [{1}] error message [{2}]".format(
        self.file_name, self.lineno, str(self.error_message))
import sys
try:
     a=1/0
except Exception as e:
     _,_,exc_tb=sys.exc_info()
     print(exc_tb.tb_lineno)
     print(exc_tb.tb_frame.f_code.co_filename)
     
     print(e)
class customexception(Exception):
    def __init__(self):
        pass
    
    def __str__(self):
        pass
raise customexception(e,sys)
os.makedirs(os.path.dirname(os.path.join("artifacts","raw.csv")),exist_ok=True)
# Out:
# 30
# C:\Users\USER\AppData\Local\Temp\ipykernel_7508\414212364.py
# division by zero
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 43
#      41     def __str__(self):
#      42         pass
# ---> 43 raise customexception(e,sys)
#      44 os.makedirs(os.path.dirname(os.path.join("artifacts","raw.csv")),exist_ok=True)
#
# NameError: name 'e' is not defined
